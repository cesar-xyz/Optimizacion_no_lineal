# %% [markdown]
# # Funciones de transferencia: estabilidad
# Determinar los ceros y los polos de las siguientes funciones de transferencia y graficarlos en el plano complejo S, decir si el sistema es Estable o Inestable.

# %%
# Dependencias a utilizar.
import control as ctrl
import matplotlib.pyplot as plt
from control.pzmap import pzmap

# %% [markdown]
# ## 1) $\frac{(s+1)(s-1)}{s(s+2)(s+10)}$
# \
# $(s+1)(s-1) = s^2-1$
# \
# $s(s+2)(s+10)= s^3+12s^2+20s$

# %%
num = [1,0,1]
den = [1,12,20,0]
sys = ctrl.tf(num, den)
print(sys)

sys_cl = ctrl.feedback(sys, 2)

#Respuesta al escalón
t, y = ctrl.step_response(sys_cl)
# Out:
#       s^2 + 1
# -------------------
# s^3 + 12 s^2 + 20 s

# %%
#Graficas
plt.plot(t, y)
plt.grid(True)
plt.title(u"Respuesta al escalón")
plt.xlabel("segundos")
# Out:
# Text(0.5, 0, 'segundos')

# %%
polos, zeros = pzmap(sys_cl), plt.grid(True)

# %% [markdown]
# #### El sistema es **estable**

# %% [markdown]
# ## 2) $\frac{s^2+2}{s^2-10s+8}$

# %%
num = [1,0,2]
den = [1,-10,8]
sys = ctrl.tf(num, den)
print(sys)

sys_cl = ctrl.feedback(sys, 2)

#Respuesta al escalón
t, y = ctrl.step_response(sys_cl)
# Out:
#    s^2 + 2
# --------------
# s^2 - 10 s + 8

# %%
#Graficas
plt.plot(t, y)
plt.grid(True)
plt.title(u"Respuesta al escalón")
plt.xlabel("segundos")
# Out:
# Text(0.5, 0, 'segundos')

# %%
polos, zeros = pzmap(sys_cl), plt.grid(True)

# %% [markdown]
# #### El sistema es **inestable**

# %% [markdown]
# ## 3) $\frac{1}{(s+2)(s^2+10s+7)}$
# \
# $(s+2)(s^2+10s+7) = s^3+12s^2+27s+14$

# %%
num = [1]
den = [1,12,27,14]
sys = ctrl.tf(num, den)
print(sys)

sys_cl = ctrl.feedback(sys, 2)

#Respuesta al escalón
t, y = ctrl.step_response(sys_cl)
# Out:
#            1
# ------------------------
# s^3 + 12 s^2 + 27 s + 14

# %%
#Graficas
plt.plot(t, y)
plt.grid(True)
plt.title(u"Respuesta al escalón")
plt.xlabel("segundos")
# Out:
# Text(0.5, 0, 'segundos')

# %%
polos, zeros = pzmap(sys_cl), plt.grid(True)

# %% [markdown]
# #### El sistema es **estable**

# %% [markdown]
# ## 4) $\frac{s+1}{(s+1)(10s+4)}$
# \
# $(s+1)(10s+4)= 10s^2+14s+4$

# %%
num = [1,1]
den = [10,14,4]
sys = ctrl.tf(num, den)
print(sys)

sys_cl = ctrl.feedback(sys, 2)

#Respuesta al escalón
t, y = ctrl.step_response(sys_cl)
# Out:
#       s + 1
# -----------------
# 10 s^2 + 14 s + 4

# %%
#Graficas
plt.plot(t, y)
plt.grid(True)
plt.title(u"Respuesta al escalón")
plt.xlabel("segundos")
# Out:
# Text(0.5, 0, 'segundos')

# %%
polos, zeros = pzmap(sys_cl), plt.grid(True)

# %% [markdown]
# #### El sistema es **estable**

# %% [markdown]
# ## 5) $\frac{1}{(s+2)(s^2+1)^2}$
# \
# $(s+2)(s^2+1)^2= s^5+2s^4+2s^3+4s^2+s+2$

# %%
num = [1]
den = [1,2,2,4,1,2]
sys = ctrl.tf(num, den)
print(sys)

sys_cl = ctrl.feedback(sys, 2)

#Respuesta al escalón
t, y = ctrl.step_response(sys_cl)
# Out:
#                  1
# -----------------------------------
# s^5 + 2 s^4 + 2 s^3 + 4 s^2 + s + 2

# %%
#Graficas
plt.plot(t, y)
plt.grid(True)
plt.title(u"Respuesta al escalón")
plt.xlabel("segundos")
# Out:
# Text(0.5, 0, 'segundos')

# %%
polos, zeros = pzmap(sys_cl), plt.grid(True)

# %% [markdown]
# #### El sistema es **inestable**

# %%
num = [1,3]
den = [1,5,2,9]
sys = ctrl.tf(num, den)
print(sys)

sys_cl = ctrl.feedback(sys, 2)

#Respuesta al escalón
t, y = ctrl.step_response(sys_cl)
# Out:
#         s + 3
# ---------------------
# s^3 + 5 s^2 + 2 s + 9

# %%
sys
# Out:
# TransferFunction(array([1, 3]), array([1, 5, 2, 9]))

# %%
#Graficas
plt.plot(t, y)
plt.grid(True)
plt.title(u"Respuesta al escalón")
plt.xlabel("segundos")
# Out:
# Text(0.5, 0, 'segundos')

# %%
polos, zeros = pzmap(sys_cl), plt.grid(True)

# %%
num = [4]
den = [1,0,0]
sys = ctrl.tf(num, den)
print(sys)

sys_cl = ctrl.feedback(sys, 2)

#Respuesta al escalón
t, y = ctrl.step_response(sys_cl)
# Out:
#  4
# ---
# s^2

# %%
#Graficas
plt.plot(t, y)
plt.grid(True)
plt.title(u"Respuesta al escalón")
plt.xlabel("segundos")
# Out:
# Text(0.5, 0, 'segundos')
